# %%
from typing import Optional, List
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

#스택 프레임 사용 : 재귀보다 성능이 좋음.
class Solution:
    def postorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        stack = [root]
        visit = [False]
        res = []

        while stack:
            cur, v = stack.pop(), visit.pop()
            if cur:
                if v:  # visited
                    res.append(cur.val)
                else:
                    stack.append(cur)
                    visit.append(True)
                    stack.append(cur.right)
                    visit.append(False)
                    stack.append(cur.left)
                    visit.append(False)
        return res
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        cur, stack = root, []
        res = []
        while cur or stack:
            if cur:
                res.append(cur.val)
                stack.append(cur.right)
                cur = cur.left
            else:
                cur = stack.pop()  # Pop from the stack
            
        return res
    
    def inorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        res = []
        stack = []
        cur = root

        while cur or stack:
            while cur:
                stack.append(cur)
                cur = cur.left
            cur = stack.pop()
            res.append(cur.val)
            cur = cur.right

        return res
        
        res = []
        def inorder(root):
            if not root:
                return
            inorder(root.left)
            res.append(root.val)
            inorder(root.right)
        inorder(root)
        return res

# %%
# Define a binary tree
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

# Create an instance of the Solution class
solution = Solution()

result = solution.preorderTraversal(root)
print(result)

# %%
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
solution_inorder=Solution()
result = solution_inorder.inorder_rec(root)


    # 왼쪽 서브트리로 이동
        inorder_rec(cur.left)
    #방문
        print(cur.val, end=' ')

    #오른쪽 서브트리로 이동
        inorder_rec(cur.right)

# %%
# Test cases
if __name__ == "__main__":
    # Example 1
    # Constructing the tree:    1
    #                         /   \
    #                        2     3
    root1 = TreeNode(1)
    root1.left = TreeNode(2)
    root1.right = TreeNode(3)
    solution = Solution()
    print(solution.postorderTraversal(root1))  # Output: [2, 3, 1]

    # Example 2
    # Constructing the tree:    1
    #                          /
    #                         2
    root2 = TreeNode(1)
    root2.left = TreeNode(2)
    print(solution.postorderTraversal(root2))  # Output: [2, 1]

    # Example 3
    # Constructing the tree:    1
    #                           \
    #                            2
    root3 = TreeNode(1)
    root3.right = TreeNode(2)
    print(solution.postorderTraversal(root3))  # Output: [2, 1]

    # Example 4
    # Constructing the tree:    1
    #                         /   \
    #                        2     3
    #                       / \
    #                      4   5
    root4 = TreeNode(1)
    root4.left = TreeNode(2)
    root4.right = TreeNode(3)
    root4.left.left = TreeNode(4)
    root4.left.right = TreeNode(5)
    print(solution.postorderTraversal(root4))
# Out:
# [2, 3, 1]
# [2, 1]
# [2, 1]
# [4, 5, 2, 3, 1]
